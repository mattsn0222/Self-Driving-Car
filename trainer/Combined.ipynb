# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Traffic Light Recognition Classifier Combined MobileNet with FabLeNet

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
import sys
import csv
import numpy as np
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
import cv2

# %matplotlib inline

GRAPH_MOBILENET="frozen_inference_graph.pb"
inference_map_text=["Red", "Yellow", "Green", "none"]
inference_map_code=['TrafficLight.RED', 'TrafficLight.YELLOW', 'TrafficLight.GREEN', 'TrafficLight.UNKNOWN']

fablenet_map_text=["Red", "Yellow", "Green"]

def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

def load_graph(graph_file):
    graph = tf.Graph()
    with graph.as_default():
        od_graph_def = tf.GraphDef()
        with tf.gfile.GFile(graph_file, 'rb') as fid:
            serialized_graph = fid.read()
            od_graph_def.ParseFromString(serialized_graph)
            tf.import_graph_def(od_graph_def, name='')
    return graph

def to_image_coords (boxes, height, width):
    box_coords=np.zeros_like(boxes)
    box_coords[:, 0] = boxes[:, 0] *  height
    box_coords[:, 1] = boxes[:, 1] * width
    box_coords[:, 2] = boxes[:, 2] * height
    box_coords[:, 3] = boxes[:, 3] * width

    return box_coords

def draw_boxes(cv_image, box_coords, classes):
        for box, cls in zip(box_coords, classes):
            color = (255,255,255)
            if cls == 10:
                color = (0,0,255)
            cv2.rectangle(cv_image, (box[1],box[0]), (box[3], box[2]), color=color, thickness=2)

class TLClassifier(object):
    def __init__(self):
        detection_graph = load_graph(GRAPH_MOBILENET)

        # The input placeholder for the image.
        self.image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')

        # Each box represents a part of the image where a particular object was detected.
        self.detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')

        # Each score represent how level of confidence for each of the objects.
        # Score is shown on the result image, together with the class label.
        self.detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')

        # The classification of the object (integer id).
        self.detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')

        self.tf_session = tf.Session(graph=detection_graph)
        

    def mobilenet_preprocess(self, cv_image):
        x = cv_image/128.
        x -= 0.5
        return x
    
    def perform_detect_ssd(self, cv_image):
        cv_image = cv2.resize(cv_image, (300, 300))
        preprocessed_input = self.mobilenet_preprocess(cv_image)
        (boxes, scores, classes) = self.tf_session.run([self.detection_boxes, self.detection_scores, self.detection_classes],
                                            feed_dict={self.image_tensor: (cv_image, )})

        # Remove unnecessary dimensions
        boxes = np.squeeze(boxes)
        scores = np.squeeze(scores)
        classes = np.squeeze(classes)

        n = len(classes)
        min_score = 0.25
        idxs=[]
        tl_idxs=[]
        for i in range(n):
            if scores[i] >= min_score:
                idxs.append(i)
                if classes[i]==10:
                    tl_idxs.append(i)

        filtered_boxes = boxes[idxs, ...]
        filtered_scores = scores[idxs, ...]
        filtered_classes = classes[idxs, ...]

        #print(filtered_scores, filtered_classes)
        height, width, _ = cv_image.shape
        box_coords = to_image_coords(filtered_boxes, height, width)

        draw_boxes(cv_image, box_coords, filtered_classes)

        return cv_image, boxes[tl_idxs, ...]


#mobile_graph = load_graph(GRAPH_MOBILENET)
#tf_session = tf.Session(graph=mobile_graph)
#op_list = mobile_graph.get_operations()
#print(len(op_list))
#with open('mobilenet_tensors.txt', 'w') as f:
#    for l in op_list:
#        f.write(l.name+'\n')
def resize32(s_img):
    x=s_img.shape[1]
    y=s_img.shape[0]
    if (x>32 or y>32):
        if (x>y):
            s_img=cv2.resize(s_img, (32, y*32//x))
        else:
            s_img=cv2.resize(s_img, (x*32//y, 32))
    l_img = np.zeros((32,32,3), dtype=np.uint8)
    x_offset = (32-s_img.shape[1])//2
    y_offset = (32-s_img.shape[0])//2
    l_img[y_offset:y_offset+s_img.shape[0], x_offset:x_offset+s_img.shape[1]] = s_img
    return l_img

def modify_images(X_data):
    arr=X_data.copy()
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(4,4))
    for idx in range(len(arr)):
        arr[idx] = cv2.cvtColor(arr[idx], cv2.COLOR_RGB2LAB)
        l_clahe = clahe.apply(arr[idx,:,:,0])
        arr[idx,:,:,0] = l_clahe
        m = np.max(arr[idx,:,:,0])
        if (m>1):
            arr[idx,:,:,0]=np.uint8(np.float32(arr[idx,:,:,0])*255/m)
        arr[idx] = cv2.cvtColor(arr[idx], cv2.COLOR_LAB2RGB)
    return (np.float32(arr[:,:,:,:])-128)/128

FabLeNet_graph = load_graph("model/fablenet.pb")
FabLeNet = tf.Session(graph=FabLeNet_graph)
#tf.train.Saver().restore(FabLeNet, "./lenet")
#top5_operation = tf.nn.top_k(tf.nn.softmax(logits), 5)

#op_list = FabLeNet_graph.get_operations()
#print(len(op_list))
#with open('fablenetnet_tensors.txt', 'w') as f:
#    for l in op_list:
#        f.write(l.name+'\n')

fablenet_input = FabLeNet_graph.get_tensor_by_name('input:0')
fablenet_dropkeep = FabLeNet_graph.get_tensor_by_name('Placeholder_1:0')
fablenet_result = FabLeNet_graph.get_tensor_by_name('result:0')
top3_operation = tf.nn.top_k(tf.nn.softmax(fablenet_result), 3)

# %%
classifier = TLClassifier()

def annotate_image(test1):
    #test1 = cv2.imread('lisa_yellow2.jpg')
    #test1 = cv2.imread('test_green.png')
    #test1 = cv2.imread('just_0386.png')
    test1rgb = cv2.cvtColor(test1, cv2.COLOR_BGR2RGB)
    #test1 = cv2.imread('test_red.png')
    #plt.figure(figsize=(12, 8))
    #plt.imshow(test1)
    #plt.show()
    res1, filtered_boxes=classifier.perform_detect_ssd(test1rgb)
    #print(filtered_boxes, test1.shape)
    box_coords = to_image_coords(filtered_boxes, test1rgb.shape[0], test1rgb.shape[1])
    
    line_idx=0
    for box in box_coords:
        #print(box)
        box=box.astype(int)
        if box[2]>box[0] and box[3]>box[1]:
            crop=test1rgb[box[0]:box[2],box[1]:box[3]]
            #plt.figure(figsize=(3, 3))
            #plt.imshow(crop)
            #plt.show()
            res=resize32(crop)
            ##res=cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
            #plt.figure(figsize=(3, 3))
            #plt.imshow(res)
            #plt.show()
            top3 = FabLeNet.run(top3_operation, feed_dict={fablenet_input: modify_images(np.array([res])), fablenet_dropkeep: 1.0})
            for idx in range(len(top3.values)):
                for n in range(len(top3.values[0])):
                    #print(fablenet_map_text[top3.indices[idx, n]], "{:.4f}".format(top3.values[idx, n]))
                    #draw.text((0, line_idx*10), "%s {:.4f}".format( fablenet_map_text[top3.indices[idx, n]], top3.values[idx, n]), (255, 255, 255), font=font)
                    text="{} {:.4f}".format( fablenet_map_text[top3.indices[idx, n]], top3.values[idx, n])
                    cv2.putText(res1,text, (10,line_idx*15+20), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (255,255,255),1)
                    line_idx+=1
    return res1

import os
dirname='img_just_416/'

for i in os.listdir(dirname):
    print(i)
    test1 = cv2.imread(dirname+i)
    res1=annotate_image(test1)
    print('out_'+dirname+i)
    cv2.imwrite('out_'+dirname+i, cv2.cvtColor(res1, cv2.COLOR_RGB2BGR))

print("ready.")
#plt.figure(figsize=(12, 8))
#plt.imshow(res1)
#plt.show()
# Out:
# just_0000.png
# out_img_just_416/just_0000.png
# just_0001.png
# out_img_just_416/just_0001.png
# just_0002.png
# out_img_just_416/just_0002.png
# just_0003.png
# out_img_just_416/just_0003.png
# just_0004.png
# out_img_just_416/just_0004.png
# just_0005.png
# out_img_just_416/just_0005.png
# just_0006.png
# out_img_just_416/just_0006.png
# just_0007.png
# out_img_just_416/just_0007.png
# just_0008.png
# out_img_just_416/just_0008.png
# just_0009.png
# out_img_just_416/just_0009.png
# just_0010.png
# out_img_just_416/just_0010.png
# just_0011.png
# out_img_just_416/just_0011.png
# just_0012.png
# out_img_just_416/just_0012.png
# just_0013.png
# out_img_just_416/just_0013.png
# just_0014.png
# out_img_just_416/just_0014.png
# just_0015.png
# out_img_just_416/just_0015.png
# just_0016.png
# out_img_just_416/just_0016.png
# just_0017.png
# out_img_just_416/just_0017.png
# just_0018.png
# out_img_just_416/just_0018.png
# just_0019.png
# out_img_just_416/just_0019.png
# just_0020.png
# out_img_just_416/just_0020.png
# just_0021.png
# out_img_just_416/just_0021.png
# just_0022.png
# out_img_just_416/just_0022.png
# just_0023.png
# out_img_just_416/just_0023.png
# just_0024.png
# out_img_just_416/just_0024.png
# just_0025.png
# out_img_just_416/just_0025.png
# just_0026.png
# out_img_just_416/just_0026.png
# just_0027.png
# out_img_just_416/just_0027.png
# just_0028.png
# out_img_just_416/just_0028.png
# just_0029.png
# out_img_just_416/just_0029.png
# just_0030.png
# out_img_just_416/just_0030.png
# just_0031.png
# out_img_just_416/just_0031.png
# just_0032.png
# out_img_just_416/just_0032.png
# just_0033.png
# out_img_just_416/just_0033.png
# just_0034.png
# out_img_just_416/just_0034.png
# just_0035.png
# out_img_just_416/just_0035.png
# just_0036.png
# out_img_just_416/just_0036.png
# just_0037.png
# out_img_just_416/just_0037.png
# just_0038.png
# out_img_just_416/just_0038.png
# just_0039.png
# out_img_just_416/just_0039.png
# just_0040.png
# out_img_just_416/just_0040.png
# just_0041.png
# out_img_just_416/just_0041.png
# just_0042.png
# out_img_just_416/just_0042.png
# just_0043.png
# out_img_just_416/just_0043.png
# just_0044.png
# out_img_just_416/just_0044.png
# just_0045.png
# out_img_just_416/just_0045.png
# just_0046.png
# out_img_just_416/just_0046.png
# just_0047.png
# out_img_just_416/just_0047.png
# just_0048.png
# out_img_just_416/just_0048.png
# just_0049.png
# out_img_just_416/just_0049.png
# just_0050.png
# out_img_just_416/just_0050.png
# just_0051.png
# out_img_just_416/just_0051.png
# just_0052.png
# out_img_just_416/just_0052.png
# just_0053.png
# out_img_just_416/just_0053.png
# just_0054.png
# out_img_just_416/just_0054.png
# just_0055.png
# out_img_just_416/just_0055.png
# just_0056.png
# out_img_just_416/just_0056.png
# just_0057.png
# out_img_just_416/just_0057.png
# just_0058.png
# out_img_just_416/just_0058.png
# just_0059.png
# out_img_just_416/just_0059.png
# just_0060.png
# out_img_just_416/just_0060.png
# just_0061.png
# out_img_just_416/just_0061.png
# just_0062.png
# out_img_just_416/just_0062.png
# just_0063.png
# out_img_just_416/just_0063.png
# just_0064.png
# out_img_just_416/just_0064.png
# just_0065.png
# out_img_just_416/just_0065.png
# just_0066.png
# out_img_just_416/just_0066.png
# just_0067.png
# out_img_just_416/just_0067.png
# just_0068.png
# out_img_just_416/just_0068.png
# just_0069.png
# out_img_just_416/just_0069.png
# just_0070.png
# out_img_just_416/just_0070.png
# just_0071.png
# out_img_just_416/just_0071.png
# just_0072.png
# out_img_just_416/just_0072.png
# just_0073.png
# out_img_just_416/just_0073.png
# just_0074.png
# out_img_just_416/just_0074.png
# just_0075.png
# out_img_just_416/just_0075.png
# just_0076.png
# out_img_just_416/just_0076.png
# just_0077.png
# out_img_just_416/just_0077.png
# just_0078.png
# out_img_just_416/just_0078.png
# just_0079.png
# out_img_just_416/just_0079.png
# just_0080.png
# out_img_just_416/just_0080.png
# just_0081.png
# out_img_just_416/just_0081.png
# just_0082.png
# out_img_just_416/just_0082.png
# just_0083.png
# out_img_just_416/just_0083.png
# just_0084.png
# out_img_just_416/just_0084.png
# just_0085.png
# out_img_just_416/just_0085.png
# just_0086.png
# out_img_just_416/just_0086.png
# just_0087.png
# out_img_just_416/just_0087.png
# just_0088.png
# out_img_just_416/just_0088.png
# just_0089.png
# out_img_just_416/just_0089.png
# just_0090.png
# out_img_just_416/just_0090.png
# just_0091.png
# out_img_just_416/just_0091.png
# just_0092.png
# out_img_just_416/just_0092.png
# just_0093.png
# out_img_just_416/just_0093.png
# just_0094.png
# out_img_just_416/just_0094.png
# just_0095.png
# out_img_just_416/just_0095.png
# just_0096.png
# out_img_just_416/just_0096.png
# just_0097.png
# out_img_just_416/just_0097.png
# just_0098.png
# out_img_just_416/just_0098.png
# just_0099.png
# out_img_just_416/just_0099.png
# just_0100.png
# out_img_just_416/just_0100.png
# just_0101.png
# out_img_just_416/just_0101.png
# just_0102.png
# out_img_just_416/just_0102.png
# just_0103.png
# out_img_just_416/just_0103.png
# just_0104.png
# out_img_just_416/just_0104.png
# just_0105.png
# out_img_just_416/just_0105.png
# just_0106.png
# out_img_just_416/just_0106.png
# just_0107.png
# out_img_just_416/just_0107.png
# just_0108.png
# out_img_just_416/just_0108.png
# just_0109.png
# out_img_just_416/just_0109.png
# just_0110.png
# out_img_just_416/just_0110.png
# just_0111.png
# out_img_just_416/just_0111.png
# just_0112.png
# out_img_just_416/just_0112.png
# just_0113.png
# out_img_just_416/just_0113.png
# just_0114.png
# out_img_just_416/just_0114.png
# just_0115.png
# out_img_just_416/just_0115.png
# just_0116.png
# out_img_just_416/just_0116.png
# just_0117.png
# out_img_just_416/just_0117.png
# just_0118.png
# out_img_just_416/just_0118.png
# just_0119.png
# out_img_just_416/just_0119.png
# just_0120.png
# out_img_just_416/just_0120.png
# just_0121.png
# out_img_just_416/just_0121.png
# just_0122.png
# out_img_just_416/just_0122.png
# just_0123.png
# out_img_just_416/just_0123.png
# just_0124.png
# out_img_just_416/just_0124.png
# just_0125.png
# out_img_just_416/just_0125.png
# just_0126.png
# out_img_just_416/just_0126.png
# just_0127.png
# out_img_just_416/just_0127.png
# just_0128.png
# out_img_just_416/just_0128.png
# just_0129.png
# out_img_just_416/just_0129.png
# just_0130.png
# out_img_just_416/just_0130.png
# just_0131.png
# out_img_just_416/just_0131.png
# just_0132.png
# out_img_just_416/just_0132.png
# just_0133.png
# out_img_just_416/just_0133.png
# just_0134.png
# out_img_just_416/just_0134.png
# just_0135.png
# out_img_just_416/just_0135.png
# just_0136.png
# out_img_just_416/just_0136.png
# just_0137.png
# out_img_just_416/just_0137.png
# just_0138.png
# out_img_just_416/just_0138.png
# just_0139.png
# out_img_just_416/just_0139.png
# just_0140.png
# out_img_just_416/just_0140.png
# just_0141.png
# out_img_just_416/just_0141.png
# just_0142.png
# out_img_just_416/just_0142.png
# just_0143.png
# out_img_just_416/just_0143.png
# just_0144.png
# out_img_just_416/just_0144.png
# just_0145.png
# out_img_just_416/just_0145.png
# just_0146.png
# out_img_just_416/just_0146.png
# just_0147.png
# out_img_just_416/just_0147.png
# just_0148.png
# out_img_just_416/just_0148.png
# just_0149.png
# out_img_just_416/just_0149.png
# just_0150.png
# out_img_just_416/just_0150.png
# just_0151.png
# out_img_just_416/just_0151.png
# just_0152.png
# out_img_just_416/just_0152.png
# just_0153.png
# out_img_just_416/just_0153.png
# just_0154.png
# out_img_just_416/just_0154.png
# just_0155.png
# out_img_just_416/just_0155.png
# just_0156.png
# out_img_just_416/just_0156.png
# just_0157.png
# out_img_just_416/just_0157.png
# just_0158.png
# out_img_just_416/just_0158.png
# just_0159.png
# out_img_just_416/just_0159.png
# just_0160.png
# out_img_just_416/just_0160.png
# just_0161.png
# out_img_just_416/just_0161.png
# just_0162.png
# out_img_just_416/just_0162.png
# just_0163.png
# out_img_just_416/just_0163.png
# just_0164.png
# out_img_just_416/just_0164.png
# just_0165.png
# out_img_just_416/just_0165.png
# just_0166.png
# out_img_just_416/just_0166.png
# just_0167.png
# out_img_just_416/just_0167.png
# just_0168.png
# out_img_just_416/just_0168.png
# just_0169.png
# out_img_just_416/just_0169.png
# just_0170.png
# out_img_just_416/just_0170.png
# just_0171.png
# out_img_just_416/just_0171.png
# just_0172.png
# out_img_just_416/just_0172.png
# just_0173.png
# out_img_just_416/just_0173.png
# just_0174.png
# out_img_just_416/just_0174.png
# just_0175.png
# out_img_just_416/just_0175.png
# just_0176.png
# out_img_just_416/just_0176.png
# just_0177.png
# out_img_just_416/just_0177.png
# just_0178.png
# out_img_just_416/just_0178.png
# just_0179.png
# out_img_just_416/just_0179.png
# just_0180.png
# out_img_just_416/just_0180.png
# just_0181.png
# out_img_just_416/just_0181.png
# just_0182.png
# out_img_just_416/just_0182.png
# just_0183.png
# out_img_just_416/just_0183.png
# just_0184.png
# out_img_just_416/just_0184.png
# just_0185.png
# out_img_just_416/just_0185.png
# just_0186.png
# out_img_just_416/just_0186.png
# just_0187.png
# out_img_just_416/just_0187.png
# just_0188.png
# out_img_just_416/just_0188.png
# just_0189.png
# out_img_just_416/just_0189.png
# just_0190.png
# out_img_just_416/just_0190.png
# just_0191.png
# out_img_just_416/just_0191.png
# just_0192.png
# out_img_just_416/just_0192.png
# just_0193.png
# out_img_just_416/just_0193.png
# just_0194.png
# out_img_just_416/just_0194.png
# just_0195.png
# out_img_just_416/just_0195.png
# just_0196.png
# out_img_just_416/just_0196.png
# just_0197.png
# out_img_just_416/just_0197.png
# just_0198.png
# out_img_just_416/just_0198.png
# just_0199.png
# out_img_just_416/just_0199.png
# just_0200.png
# out_img_just_416/just_0200.png
# just_0201.png
# out_img_just_416/just_0201.png
# just_0202.png
# out_img_just_416/just_0202.png
# just_0203.png
# out_img_just_416/just_0203.png
# just_0204.png
# out_img_just_416/just_0204.png
# just_0205.png
# out_img_just_416/just_0205.png
# just_0206.png
# out_img_just_416/just_0206.png
# just_0207.png
# out_img_just_416/just_0207.png
# just_0208.png
# out_img_just_416/just_0208.png
# just_0209.png
# out_img_just_416/just_0209.png
# just_0210.png
# out_img_just_416/just_0210.png
# just_0211.png
# out_img_just_416/just_0211.png
# just_0212.png
# out_img_just_416/just_0212.png
# just_0213.png
# out_img_just_416/just_0213.png
# just_0214.png
# out_img_just_416/just_0214.png
# just_0215.png
# out_img_just_416/just_0215.png
# just_0216.png
# out_img_just_416/just_0216.png
# just_0217.png
# out_img_just_416/just_0217.png
# just_0218.png
# out_img_just_416/just_0218.png
# just_0219.png
# out_img_just_416/just_0219.png
# just_0220.png
# out_img_just_416/just_0220.png
# just_0221.png
# out_img_just_416/just_0221.png
# just_0222.png
# out_img_just_416/just_0222.png
# just_0223.png
# out_img_just_416/just_0223.png
# just_0224.png
# out_img_just_416/just_0224.png
# just_0225.png
# out_img_just_416/just_0225.png
# just_0226.png
# out_img_just_416/just_0226.png
# just_0227.png
# out_img_just_416/just_0227.png
# just_0228.png
# out_img_just_416/just_0228.png
# just_0229.png
# out_img_just_416/just_0229.png
# just_0230.png
# out_img_just_416/just_0230.png
# just_0231.png
# out_img_just_416/just_0231.png
# just_0232.png
# out_img_just_416/just_0232.png
# just_0233.png
# out_img_just_416/just_0233.png
# just_0234.png
# out_img_just_416/just_0234.png
# just_0235.png
# out_img_just_416/just_0235.png
# just_0236.png
# out_img_just_416/just_0236.png
# just_0237.png
# out_img_just_416/just_0237.png
# just_0238.png
# out_img_just_416/just_0238.png
# just_0239.png
# out_img_just_416/just_0239.png
# just_0240.png
# out_img_just_416/just_0240.png
# just_0241.png
# out_img_just_416/just_0241.png
# just_0242.png
# out_img_just_416/just_0242.png
# just_0243.png
# out_img_just_416/just_0243.png
# just_0244.png
# out_img_just_416/just_0244.png
# just_0245.png
# out_img_just_416/just_0245.png
# just_0246.png
# out_img_just_416/just_0246.png
# just_0247.png
# out_img_just_416/just_0247.png
# just_0248.png
# out_img_just_416/just_0248.png
# just_0249.png
# out_img_just_416/just_0249.png
# just_0250.png
# out_img_just_416/just_0250.png
# just_0251.png
# out_img_just_416/just_0251.png
# just_0252.png
# out_img_just_416/just_0252.png
# just_0253.png
# out_img_just_416/just_0253.png
# just_0254.png
# out_img_just_416/just_0254.png
# just_0255.png
# out_img_just_416/just_0255.png
# just_0256.png
# out_img_just_416/just_0256.png
# just_0257.png
# out_img_just_416/just_0257.png
# just_0258.png
# out_img_just_416/just_0258.png
# just_0259.png
# out_img_just_416/just_0259.png
# just_0260.png
# out_img_just_416/just_0260.png
# just_0261.png
# out_img_just_416/just_0261.png
# just_0262.png
# out_img_just_416/just_0262.png
# just_0263.png
# out_img_just_416/just_0263.png
# just_0264.png
# out_img_just_416/just_0264.png
# just_0265.png
# out_img_just_416/just_0265.png
# just_0266.png
# out_img_just_416/just_0266.png
# just_0267.png
# out_img_just_416/just_0267.png
# just_0268.png
# out_img_just_416/just_0268.png
# just_0269.png
# out_img_just_416/just_0269.png
# just_0270.png
# out_img_just_416/just_0270.png
# just_0271.png
# out_img_just_416/just_0271.png
# just_0272.png
# out_img_just_416/just_0272.png
# just_0273.png
# out_img_just_416/just_0273.png
# just_0274.png
# out_img_just_416/just_0274.png
# just_0275.png
# out_img_just_416/just_0275.png
# just_0276.png
# out_img_just_416/just_0276.png
# just_0277.png
# out_img_just_416/just_0277.png
# just_0278.png
# out_img_just_416/just_0278.png
# just_0279.png
# out_img_just_416/just_0279.png
# just_0280.png
# out_img_just_416/just_0280.png
# just_0281.png
# out_img_just_416/just_0281.png
# just_0282.png
# out_img_just_416/just_0282.png
# just_0283.png
# out_img_just_416/just_0283.png
# just_0284.png
# out_img_just_416/just_0284.png
# just_0285.png
# out_img_just_416/just_0285.png
# just_0286.png
# out_img_just_416/just_0286.png
# just_0287.png
# out_img_just_416/just_0287.png
# just_0288.png
# out_img_just_416/just_0288.png
# just_0289.png
# out_img_just_416/just_0289.png
# just_0290.png
# out_img_just_416/just_0290.png
# just_0291.png
# out_img_just_416/just_0291.png
# just_0292.png
# out_img_just_416/just_0292.png
# just_0293.png
# out_img_just_416/just_0293.png
# just_0294.png
# out_img_just_416/just_0294.png
# just_0295.png
# out_img_just_416/just_0295.png
# just_0296.png
# out_img_just_416/just_0296.png
# just_0297.png
# out_img_just_416/just_0297.png
# just_0298.png
# out_img_just_416/just_0298.png
# just_0299.png
# out_img_just_416/just_0299.png
# just_0300.png
# out_img_just_416/just_0300.png
# just_0301.png
# out_img_just_416/just_0301.png
# just_0302.png
# out_img_just_416/just_0302.png
# just_0303.png
# out_img_just_416/just_0303.png
# just_0304.png
# out_img_just_416/just_0304.png
# just_0305.png
# out_img_just_416/just_0305.png
# just_0306.png
# out_img_just_416/just_0306.png
# just_0307.png
# out_img_just_416/just_0307.png
# just_0308.png
# out_img_just_416/just_0308.png
# just_0309.png
# out_img_just_416/just_0309.png
# just_0310.png
# out_img_just_416/just_0310.png
# just_0311.png
# out_img_just_416/just_0311.png
# just_0312.png
# out_img_just_416/just_0312.png
# just_0313.png
# out_img_just_416/just_0313.png
# just_0314.png
# out_img_just_416/just_0314.png
# just_0315.png
# out_img_just_416/just_0315.png
# just_0316.png
# out_img_just_416/just_0316.png
# just_0317.png
# out_img_just_416/just_0317.png
# just_0318.png
# out_img_just_416/just_0318.png
# just_0319.png
# out_img_just_416/just_0319.png
# just_0320.png
# out_img_just_416/just_0320.png
# just_0321.png
# out_img_just_416/just_0321.png
# just_0322.png
# out_img_just_416/just_0322.png
# just_0323.png
# out_img_just_416/just_0323.png
# just_0324.png
# out_img_just_416/just_0324.png
# just_0325.png
# out_img_just_416/just_0325.png
# just_0326.png
# out_img_just_416/just_0326.png
# just_0327.png
# out_img_just_416/just_0327.png
# just_0328.png
# out_img_just_416/just_0328.png
# just_0329.png
# out_img_just_416/just_0329.png
# just_0330.png
# out_img_just_416/just_0330.png
# just_0331.png
# out_img_just_416/just_0331.png
# just_0332.png
# out_img_just_416/just_0332.png
# just_0333.png
# out_img_just_416/just_0333.png
# just_0334.png
# out_img_just_416/just_0334.png
# just_0335.png
# out_img_just_416/just_0335.png
# just_0336.png
# out_img_just_416/just_0336.png
# just_0337.png
# out_img_just_416/just_0337.png
# just_0338.png
# out_img_just_416/just_0338.png
# just_0339.png
# out_img_just_416/just_0339.png
# just_0340.png
# out_img_just_416/just_0340.png
# just_0341.png
# out_img_just_416/just_0341.png
# just_0342.png
# out_img_just_416/just_0342.png
# just_0343.png
# out_img_just_416/just_0343.png
# just_0344.png
# out_img_just_416/just_0344.png
# just_0345.png
# out_img_just_416/just_0345.png
# just_0346.png
# out_img_just_416/just_0346.png
# just_0347.png
# out_img_just_416/just_0347.png
# just_0348.png
# out_img_just_416/just_0348.png
# just_0349.png
# out_img_just_416/just_0349.png
# just_0350.png
# out_img_just_416/just_0350.png
# just_0351.png
# out_img_just_416/just_0351.png
# just_0352.png
# out_img_just_416/just_0352.png
# just_0353.png
# out_img_just_416/just_0353.png
# just_0354.png
# out_img_just_416/just_0354.png
# just_0355.png
# out_img_just_416/just_0355.png
# just_0356.png
# out_img_just_416/just_0356.png
# just_0357.png
# out_img_just_416/just_0357.png
# just_0358.png
# out_img_just_416/just_0358.png
# just_0359.png
# out_img_just_416/just_0359.png
# just_0360.png
# out_img_just_416/just_0360.png
# just_0361.png
# out_img_just_416/just_0361.png
# just_0362.png
# out_img_just_416/just_0362.png
# just_0363.png
# out_img_just_416/just_0363.png
# just_0364.png
# out_img_just_416/just_0364.png
# just_0365.png
# out_img_just_416/just_0365.png
# just_0366.png
# out_img_just_416/just_0366.png
# just_0367.png
# out_img_just_416/just_0367.png
# just_0368.png
# out_img_just_416/just_0368.png
# just_0369.png
# out_img_just_416/just_0369.png
# just_0370.png
# out_img_just_416/just_0370.png
# just_0371.png
# out_img_just_416/just_0371.png
# just_0372.png
# out_img_just_416/just_0372.png
# just_0373.png
# out_img_just_416/just_0373.png
# just_0374.png
# out_img_just_416/just_0374.png
# just_0375.png
# out_img_just_416/just_0375.png
# just_0376.png
# out_img_just_416/just_0376.png
# just_0377.png
# out_img_just_416/just_0377.png
# just_0378.png
# out_img_just_416/just_0378.png
# just_0379.png
# out_img_just_416/just_0379.png
# just_0380.png
# out_img_just_416/just_0380.png
# just_0381.png
# out_img_just_416/just_0381.png
# just_0382.png
# out_img_just_416/just_0382.png
# just_0383.png
# out_img_just_416/just_0383.png
# just_0384.png
# out_img_just_416/just_0384.png
# just_0385.png
# out_img_just_416/just_0385.png
# just_0386.png
# out_img_just_416/just_0386.png
# just_0387.png
# out_img_just_416/just_0387.png
# just_0388.png
# out_img_just_416/just_0388.png
# just_0389.png
# out_img_just_416/just_0389.png
# just_0390.png
# out_img_just_416/just_0390.png
# just_0391.png
# out_img_just_416/just_0391.png
# just_0392.png
# out_img_just_416/just_0392.png
# just_0393.png
# out_img_just_416/just_0393.png
# just_0394.png
# out_img_just_416/just_0394.png
# just_0395.png
# out_img_just_416/just_0395.png
# just_0396.png
# out_img_just_416/just_0396.png
# just_0397.png
# out_img_just_416/just_0397.png
# just_0398.png
# out_img_just_416/just_0398.png
# just_0399.png
# out_img_just_416/just_0399.png
# just_0400.png
# out_img_just_416/just_0400.png
# just_0401.png
# out_img_just_416/just_0401.png
# just_0402.png
# out_img_just_416/just_0402.png
# just_0403.png
# out_img_just_416/just_0403.png
# just_0404.png
# out_img_just_416/just_0404.png
# just_0405.png
# out_img_just_416/just_0405.png
# just_0406.png
# out_img_just_416/just_0406.png
# just_0407.png
# out_img_just_416/just_0407.png
# just_0408.png
# out_img_just_416/just_0408.png
# just_0409.png
# out_img_just_416/just_0409.png
# just_0410.png
# out_img_just_416/just_0410.png
# just_0411.png
# out_img_just_416/just_0411.png
# just_0412.png
# out_img_just_416/just_0412.png
# just_0413.png
# out_img_just_416/just_0413.png
# just_0414.png
# out_img_just_416/just_0414.png
# just_0415.png
# out_img_just_416/just_0415.png
# just_0416.png
# out_img_just_416/just_0416.png
# just_0417.png
# out_img_just_416/just_0417.png
# just_0418.png
# out_img_just_416/just_0418.png
# just_0419.png
# out_img_just_416/just_0419.png
# just_0420.png
# out_img_just_416/just_0420.png
# just_0421.png
# out_img_just_416/just_0421.png
# just_0422.png
# out_img_just_416/just_0422.png
# just_0423.png
# out_img_just_416/just_0423.png
# just_0424.png
# out_img_just_416/just_0424.png
# just_0425.png
# out_img_just_416/just_0425.png
# just_0426.png
# out_img_just_416/just_0426.png
# just_0427.png
# out_img_just_416/just_0427.png
# just_0428.png
# out_img_just_416/just_0428.png
# just_0429.png
# out_img_just_416/just_0429.png
# just_0430.png
# out_img_just_416/just_0430.png
# just_0431.png
# out_img_just_416/just_0431.png
# just_0432.png
# out_img_just_416/just_0432.png
# just_0433.png
# out_img_just_416/just_0433.png
# just_0434.png
# out_img_just_416/just_0434.png
# just_0435.png
# out_img_just_416/just_0435.png
# just_0436.png
# out_img_just_416/just_0436.png
# just_0437.png
# out_img_just_416/just_0437.png
# just_0438.png
# out_img_just_416/just_0438.png
# just_0439.png
# out_img_just_416/just_0439.png
# just_0440.png
# out_img_just_416/just_0440.png
# just_0441.png
# out_img_just_416/just_0441.png
# just_0442.png
# out_img_just_416/just_0442.png
# just_0443.png
# out_img_just_416/just_0443.png
# just_0444.png
# out_img_just_416/just_0444.png
# just_0445.png
# out_img_just_416/just_0445.png
# just_0446.png
# out_img_just_416/just_0446.png
# just_0447.png
# out_img_just_416/just_0447.png
# just_0448.png
# out_img_just_416/just_0448.png
# just_0449.png
# out_img_just_416/just_0449.png
# just_0450.png
# out_img_just_416/just_0450.png
# just_0451.png
# out_img_just_416/just_0451.png
# just_0452.png
# out_img_just_416/just_0452.png
# just_0453.png
# out_img_just_416/just_0453.png
# just_0454.png
# out_img_just_416/just_0454.png
# just_0455.png
# out_img_just_416/just_0455.png
# just_0456.png
# out_img_just_416/just_0456.png
# just_0457.png
# out_img_just_416/just_0457.png
# just_0458.png
# out_img_just_416/just_0458.png
# just_0459.png
# out_img_just_416/just_0459.png
# just_0460.png
# out_img_just_416/just_0460.png
# just_0461.png
# out_img_just_416/just_0461.png
# just_0462.png
# out_img_just_416/just_0462.png
# just_0463.png
# out_img_just_416/just_0463.png
# just_0464.png
# out_img_just_416/just_0464.png
# just_0465.png
# out_img_just_416/just_0465.png
# just_0466.png
# out_img_just_416/just_0466.png
# just_0467.png
# out_img_just_416/just_0467.png
# just_0468.png
# out_img_just_416/just_0468.png
# just_0469.png
# out_img_just_416/just_0469.png
# just_0470.png
# out_img_just_416/just_0470.png
# just_0471.png
# out_img_just_416/just_0471.png
# just_0472.png
# out_img_just_416/just_0472.png
# just_0473.png
# out_img_just_416/just_0473.png
# just_0474.png
# out_img_just_416/just_0474.png
# just_0475.png
# out_img_just_416/just_0475.png
# just_0476.png
# out_img_just_416/just_0476.png
# just_0477.png
# out_img_just_416/just_0477.png
# just_0478.png
# out_img_just_416/just_0478.png
# just_0479.png
# out_img_just_416/just_0479.png
# just_0480.png
# out_img_just_416/just_0480.png
# just_0481.png
# out_img_just_416/just_0481.png
# just_0482.png
# out_img_just_416/just_0482.png
# just_0483.png
# out_img_just_416/just_0483.png
# just_0484.png
# out_img_just_416/just_0484.png
# just_0485.png
# out_img_just_416/just_0485.png
# just_0486.png
# out_img_just_416/just_0486.png
# just_0487.png
# out_img_just_416/just_0487.png
# just_0488.png
# out_img_just_416/just_0488.png
# just_0489.png
# out_img_just_416/just_0489.png
# just_0490.png
# out_img_just_416/just_0490.png
# just_0491.png
# out_img_just_416/just_0491.png
# just_0492.png
# out_img_just_416/just_0492.png
# just_0493.png
# out_img_just_416/just_0493.png
# just_0494.png
# out_img_just_416/just_0494.png
# just_0495.png
# out_img_just_416/just_0495.png
# just_0496.png
# out_img_just_416/just_0496.png
# just_0497.png
# out_img_just_416/just_0497.png
# just_0498.png
# out_img_just_416/just_0498.png
# just_0499.png
# out_img_just_416/just_0499.png
# just_0500.png
# out_img_just_416/just_0500.png
# just_0501.png
# out_img_just_416/just_0501.png
# just_0502.png
# out_img_just_416/just_0502.png
# just_0503.png
# out_img_just_416/just_0503.png
# just_0504.png
# out_img_just_416/just_0504.png
# just_0505.png
# out_img_just_416/just_0505.png
# just_0506.png
# out_img_just_416/just_0506.png
# just_0507.png
# out_img_just_416/just_0507.png
# just_0508.png
# out_img_just_416/just_0508.png
# just_0509.png
# out_img_just_416/just_0509.png
# just_0510.png
# out_img_just_416/just_0510.png
# just_0511.png
# out_img_just_416/just_0511.png
# just_0512.png
# out_img_just_416/just_0512.png
# just_0513.png
# out_img_just_416/just_0513.png
# just_0514.png
# out_img_just_416/just_0514.png
# just_0515.png
# out_img_just_416/just_0515.png
# just_0516.png
# out_img_just_416/just_0516.png
# just_0517.png
# out_img_just_416/just_0517.png
# just_0518.png
# out_img_just_416/just_0518.png
# just_0519.png
# out_img_just_416/just_0519.png
# just_0520.png
# out_img_just_416/just_0520.png
# just_0521.png
# out_img_just_416/just_0521.png
# just_0522.png
# out_img_just_416/just_0522.png
# just_0523.png
# out_img_just_416/just_0523.png
# just_0524.png
# out_img_just_416/just_0524.png
# just_0525.png
# out_img_just_416/just_0525.png
# just_0526.png
# out_img_just_416/just_0526.png
# just_0527.png
# out_img_just_416/just_0527.png
# just_0528.png
# out_img_just_416/just_0528.png
# just_0529.png
# out_img_just_416/just_0529.png
# just_0530.png
# out_img_just_416/just_0530.png
# just_0531.png
# out_img_just_416/just_0531.png
# just_0532.png
# out_img_just_416/just_0532.png
# just_0533.png
# out_img_just_416/just_0533.png
# just_0534.png
# out_img_just_416/just_0534.png
# just_0535.png
# out_img_just_416/just_0535.png
# just_0536.png
# out_img_just_416/just_0536.png
# just_0537.png
# out_img_just_416/just_0537.png
# just_0538.png
# out_img_just_416/just_0538.png
# just_0539.png
# out_img_just_416/just_0539.png
# just_0540.png
# out_img_just_416/just_0540.png
# just_0541.png
# out_img_just_416/just_0541.png
# just_0542.png
# out_img_just_416/just_0542.png
# just_0543.png
# out_img_just_416/just_0543.png
# just_0544.png
# out_img_just_416/just_0544.png
# just_0545.png
# out_img_just_416/just_0545.png
# just_0546.png
# out_img_just_416/just_0546.png
# just_0547.png
# out_img_just_416/just_0547.png
# just_0548.png
# out_img_just_416/just_0548.png
# just_0549.png
# out_img_just_416/just_0549.png
# just_0550.png
# out_img_just_416/just_0550.png
# just_0551.png
# out_img_just_416/just_0551.png
# just_0552.png
# out_img_just_416/just_0552.png
# just_0553.png
# out_img_just_416/just_0553.png
# just_0554.png
# out_img_just_416/just_0554.png
# just_0555.png
# out_img_just_416/just_0555.png
# just_0556.png
# out_img_just_416/just_0556.png
# just_0557.png
# out_img_just_416/just_0557.png
# just_0558.png
# out_img_just_416/just_0558.png
# just_0559.png
# out_img_just_416/just_0559.png
# just_0560.png
# out_img_just_416/just_0560.png
# just_0561.png
# out_img_just_416/just_0561.png
# just_0562.png
# out_img_just_416/just_0562.png
# just_0563.png
# out_img_just_416/just_0563.png
# just_0564.png
# out_img_just_416/just_0564.png
# just_0565.png
# out_img_just_416/just_0565.png
# just_0566.png
# out_img_just_416/just_0566.png
# just_0567.png
# out_img_just_416/just_0567.png
# just_0568.png
# out_img_just_416/just_0568.png
# just_0569.png
# out_img_just_416/just_0569.png
# just_0570.png
# out_img_just_416/just_0570.png
# just_0571.png
# out_img_just_416/just_0571.png
# just_0572.png
# out_img_just_416/just_0572.png
# just_0573.png
# out_img_just_416/just_0573.png
# just_0574.png
# out_img_just_416/just_0574.png
# just_0575.png
# out_img_just_416/just_0575.png
# just_0576.png
# out_img_just_416/just_0576.png
# just_0577.png
# out_img_just_416/just_0577.png
# just_0578.png
# out_img_just_416/just_0578.png
# just_0579.png
# out_img_just_416/just_0579.png
# just_0580.png
# out_img_just_416/just_0580.png
# just_0581.png
# out_img_just_416/just_0581.png
# just_0582.png
# out_img_just_416/just_0582.png
# just_0583.png
# out_img_just_416/just_0583.png
# just_0584.png
# out_img_just_416/just_0584.png
# just_0585.png
# out_img_just_416/just_0585.png
# just_0586.png
# out_img_just_416/just_0586.png
# just_0587.png
# out_img_just_416/just_0587.png
# just_0588.png
# out_img_just_416/just_0588.png
# just_0589.png
# out_img_just_416/just_0589.png
# just_0590.png
# out_img_just_416/just_0590.png
# just_0591.png
# out_img_just_416/just_0591.png
# just_0592.png
# out_img_just_416/just_0592.png
# just_0593.png
# out_img_just_416/just_0593.png
# just_0594.png
# out_img_just_416/just_0594.png
# just_0595.png
# out_img_just_416/just_0595.png
# just_0596.png
# out_img_just_416/just_0596.png
# just_0597.png
# out_img_just_416/just_0597.png
# just_0598.png
# out_img_just_416/just_0598.png
# just_0599.png
# out_img_just_416/just_0599.png
# just_0600.png
# out_img_just_416/just_0600.png
# just_0601.png
# out_img_just_416/just_0601.png
# just_0602.png
# out_img_just_416/just_0602.png
# just_0603.png
# out_img_just_416/just_0603.png
# just_0604.png
# out_img_just_416/just_0604.png
# just_0605.png
# out_img_just_416/just_0605.png
# just_0606.png
# out_img_just_416/just_0606.png
# just_0607.png
# out_img_just_416/just_0607.png
# just_0608.png
# out_img_just_416/just_0608.png
# just_0609.png
# out_img_just_416/just_0609.png
# just_0610.png
# out_img_just_416/just_0610.png
# just_0611.png
# out_img_just_416/just_0611.png
# just_0612.png
# out_img_just_416/just_0612.png
# just_0613.png
# out_img_just_416/just_0613.png
# just_0614.png
# out_img_just_416/just_0614.png
# just_0615.png
# out_img_just_416/just_0615.png
# just_0616.png
# out_img_just_416/just_0616.png
# just_0617.png
# out_img_just_416/just_0617.png
# just_0618.png
# out_img_just_416/just_0618.png
# just_0619.png
# out_img_just_416/just_0619.png
# just_0620.png
# out_img_just_416/just_0620.png
# just_0621.png
# out_img_just_416/just_0621.png
# just_0622.png
# out_img_just_416/just_0622.png
# just_0623.png
# out_img_just_416/just_0623.png
# just_0624.png
# out_img_just_416/just_0624.png
# just_0625.png
# out_img_just_416/just_0625.png
# just_0626.png
# out_img_just_416/just_0626.png
# just_0627.png
# out_img_just_416/just_0627.png
# just_0628.png
# out_img_just_416/just_0628.png
# just_0629.png
# out_img_just_416/just_0629.png
# just_0630.png
# out_img_just_416/just_0630.png
# just_0631.png
# out_img_just_416/just_0631.png
# just_0632.png
# out_img_just_416/just_0632.png
# just_0633.png
# out_img_just_416/just_0633.png
# just_0634.png
# out_img_just_416/just_0634.png
# just_0635.png
# out_img_just_416/just_0635.png
# just_0636.png
# out_img_just_416/just_0636.png
# just_0637.png
# out_img_just_416/just_0637.png
# just_0638.png
# out_img_just_416/just_0638.png
# just_0639.png
# out_img_just_416/just_0639.png
# just_0640.png
# out_img_just_416/just_0640.png
# just_0641.png
# out_img_just_416/just_0641.png
# just_0642.png
# out_img_just_416/just_0642.png
# just_0643.png
# out_img_just_416/just_0643.png
# just_0644.png
# out_img_just_416/just_0644.png
# just_0645.png
# out_img_just_416/just_0645.png
# just_0646.png
# out_img_just_416/just_0646.png
# just_0647.png
# out_img_just_416/just_0647.png
# just_0648.png
# out_img_just_416/just_0648.png
# just_0649.png
# out_img_just_416/just_0649.png
# just_0650.png
# out_img_just_416/just_0650.png
# just_0651.png
# out_img_just_416/just_0651.png
# just_0652.png
# out_img_just_416/just_0652.png
# just_0653.png
# out_img_just_416/just_0653.png
# just_0654.png
# out_img_just_416/just_0654.png
# just_0655.png
# out_img_just_416/just_0655.png
# just_0656.png
# out_img_just_416/just_0656.png
# just_0657.png
# out_img_just_416/just_0657.png
# just_0658.png
# out_img_just_416/just_0658.png
# just_0659.png
# out_img_just_416/just_0659.png
# just_0660.png
# out_img_just_416/just_0660.png
# just_0661.png
# out_img_just_416/just_0661.png
# just_0662.png
# out_img_just_416/just_0662.png
# just_0663.png
# out_img_just_416/just_0663.png
# just_0664.png
# out_img_just_416/just_0664.png
# just_0665.png
# out_img_just_416/just_0665.png
# just_0666.png
# out_img_just_416/just_0666.png
# just_0667.png
# out_img_just_416/just_0667.png
# just_0668.png
# out_img_just_416/just_0668.png
# just_0669.png
# out_img_just_416/just_0669.png
# just_0670.png
# out_img_just_416/just_0670.png
# just_0671.png
# out_img_just_416/just_0671.png
# just_0672.png
# out_img_just_416/just_0672.png
# just_0673.png
# out_img_just_416/just_0673.png
# just_0674.png
# out_img_just_416/just_0674.png
# just_0675.png
# out_img_just_416/just_0675.png
# just_0676.png
# out_img_just_416/just_0676.png
# just_0677.png
# out_img_just_416/just_0677.png
# just_0678.png
# out_img_just_416/just_0678.png
# just_0679.png
# out_img_just_416/just_0679.png
# just_0680.png
# out_img_just_416/just_0680.png
# just_0681.png
# out_img_just_416/just_0681.png
# just_0682.png
# out_img_just_416/just_0682.png
# just_0683.png
# out_img_just_416/just_0683.png
# just_0684.png
# out_img_just_416/just_0684.png
# just_0685.png
# out_img_just_416/just_0685.png
# just_0686.png
# out_img_just_416/just_0686.png
# just_0687.png
# out_img_just_416/just_0687.png
# just_0688.png
# out_img_just_416/just_0688.png
# just_0689.png
# out_img_just_416/just_0689.png
# just_0690.png
# out_img_just_416/just_0690.png
# just_0691.png
# out_img_just_416/just_0691.png
# just_0692.png
# out_img_just_416/just_0692.png
# just_0693.png
# out_img_just_416/just_0693.png
# just_0694.png
# out_img_just_416/just_0694.png
# just_0695.png
# out_img_just_416/just_0695.png
# just_0696.png
# out_img_just_416/just_0696.png
# just_0697.png
# out_img_just_416/just_0697.png
# just_0698.png
# out_img_just_416/just_0698.png
# just_0699.png
# out_img_just_416/just_0699.png
# just_0700.png
# out_img_just_416/just_0700.png
# just_0701.png
# out_img_just_416/just_0701.png
# just_0702.png
# out_img_just_416/just_0702.png
# just_0703.png
# out_img_just_416/just_0703.png
# just_0704.png
# out_img_just_416/just_0704.png
# just_0705.png
# out_img_just_416/just_0705.png
# just_0706.png
# out_img_just_416/just_0706.png
# just_0707.png
# out_img_just_416/just_0707.png
# just_0708.png
# out_img_just_416/just_0708.png
# just_0709.png
# out_img_just_416/just_0709.png
# just_0710.png
# out_img_just_416/just_0710.png
# just_0711.png
# out_img_just_416/just_0711.png
# ready.
